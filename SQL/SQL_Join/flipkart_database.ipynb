# %%
from sqlalchemy import create_engine
import pandas as pd


engine = create_engine(f'mysql+pymysql://root:Apurba1903@127.0.0.1:3306/flipkart')

# %%
category = pd.read_csv("C:/Users/ACER/Desktop/DSMP1/Datasets/datasets-session-34/category.csv")
order_details = pd.read_csv("C:/Users/ACER/Desktop/DSMP1/Datasets/datasets-session-34/order_details.csv")
orders = pd.read_csv("C:/Users/ACER/Desktop/DSMP1/Datasets/datasets-session-34/orders.csv")
users = pd.read_csv("C:/Users/ACER/Desktop/DSMP1/Datasets/datasets-session-34/users.csv")

# %%
category.to_sql('category', con=engine, index=False, if_exists='append', chunksize=1000)
order_details.to_sql('order_details', con=engine, index=False, if_exists='append', chunksize=1000)
orders.to_sql('orders', con=engine, index=False, if_exists='append', chunksize=1000)
users.to_sql('users', con=engine, index=False, if_exists='append', chunksize=1000)
# Out:
# 401
